# %% [markdown]
# # 🛳️ Titanic Dataset Analysis
#
# En este notebook responderemos una serie de preguntas utilizando el dataset del Titanic y la librería Pandas.
#
# El objetivo es practicar operaciones básicas de análisis de datos como:
#
# - Obtener estadísticas descriptivas.
# - Filtrar información.
# - Agrupar datos.
# - Calcular porcentajes y medias.

# %%
import pandas as pd

# %%
CSV_PATH = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"

df = pd.read_csv(CSV_PATH)
df.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 CSV_PATH = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
#       2
# ----> 3 df = pd.read_csv(CSV_PATH)
#       4 df.head(5)
#
# NameError: name 'pd' is not defined
